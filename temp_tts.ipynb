# %%
pip install --upgrade google-cloud-texttospeech
# Out:
# Collecting google-cloud-texttospeech
#   Downloading google_cloud_texttospeech-2.14.1-py2.py3-none-any.whl (118 kB)
#      -------------------------------------- 119.0/119.0 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages (from google-cloud-texttospeech) (1.22.2)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages (from google-cloud-texttospeech) (3.19.6)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0 in c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages (from google-cloud-texttospeech) (2.11.0)
# Requirement already satisfied: google-auth<3.0dev,>=2.14.1 in c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (2.16.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (2.28.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (1.58.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (1.51.1)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (1.51.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3.0dev,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3.0dev,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3.0dev,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3.0dev,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (4.7.2)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5
#   Downloading protobuf-4.22.0-cp310-abi3-win_amd64.whl (420 kB)
#      -------------------------------------- 420.6/420.6 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (1.26.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (2022.6.15)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (0.4.8)
# Installing collected packages: protobuf, google-cloud-texttospeech
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
# Successfully installed google-cloud-texttospeech-2.14.1 protobuf-4.22.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages)
#     WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.9.2 requires flatbuffers<2,>=1.12, but you have flatbuffers 23.1.21 which is incompatible.
# tensorflow 2.9.2 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.22.0 which is incompatible.
# tensorflow 2.9.2 requires tensorflow-estimator<2.10.0,>=2.9.0rc0, but you have tensorflow-estimator 2.11.0 which is incompatible.
# tensorflow-metadata 1.12.0 requires protobuf<4,>=3.13, but you have protobuf 4.22.0 which is incompatible.
# tensorboard 2.9.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.22.0 which is incompatible.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\sksoh\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
"""Synthesizes speech from the input string of text or ssml.
Make sure to be working in a virtual environment.

Note: ssml must be well-formed according to:
    https://www.w3.org/TR/speech-synthesis/
"""
import json
from google.cloud import texttospeech
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "./tts_api_key.json"

with open('./text.json', 'r', encoding="UTF-8") as f:

    json_data = json.load(f)

text = json.dumps(json_data, indent="\t", ensure_ascii=False)
# Instantiates a client
client = texttospeech.TextToSpeechClient()
# Set the text input to be synthesized
synthesis_input = texttospeech.SynthesisInput(text="Hello World!")

# Build the voice request, select the language code ("en-US") and the ssml
# voice gender ("neutral")
voice = texttospeech.VoiceSelectionParams(
    language_code="en-US", ssml_gender=texttospeech.SsmlVoiceGender.NEUTRAL
)

# Select the type of audio file you want returned
audio_config = texttospeech.AudioConfig(
    audio_encoding=texttospeech.AudioEncoding.MP3
)

# Perform the text-to-speech request on the text input with the selected
# voice parameters and audio file type
response = client.synthesize_speech(
    input=synthesis_input, voice=voice, audio_config=audio_config
)

# The response's audio_content is binary.
with open("sample.mp3", "wb") as out:
    # Write the response to the output file.
    out.write(response.audio_content)
    print('Audio content written to file "output.mp3"')
# Out:
# Audio content written to file "output.mp3"

# %%
import json
import json
from google.cloud import texttospeech
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "./tts_api_key.json"

# 저장한 파일 출력하기

with open('./text.json', 'r', encoding="utf-8") as f:

    json_data = json.load(f)

# print(json.dumps(json_data, indent="\t", ensure_ascii=False))
for i in range(1, len(json_data)+1):
    line = len(json_data[str(i)])
    for j in range(line):
        text = json_data[str(i)][j]["text"]
        # Instantiates a client
        client = texttospeech.TextToSpeechClient()
        # Set the text input to be synthesized
        synthesis_input = texttospeech.SynthesisInput(text=text)

        # Build the voice request, select the language code ("en-US") and the ssml
        # voice gender ("neutral")
        voice = texttospeech.VoiceSelectionParams(
            language_code="ko", ssml_gender=texttospeech.SsmlVoiceGender.NEUTRAL
        )

        # Select the type of audio file you want returned
        audio_config = texttospeech.AudioConfig(
            audio_encoding=texttospeech.AudioEncoding.MP3
        )

        # Perform the text-to-speech request on the text input with the selected
        # voice parameters and audio file type
        response = client.synthesize_speech(
            input=synthesis_input, voice=voice, audio_config=audio_config
        )

        # The response's audio_content is binary.
        fileName = "./audio_output/sample" + str(i) + "_" + str(j) + ".mp3"
        with open(fileName, "wb") as out:
            # Write the response to the output file.
            out.write(response.audio_content)
            print('Audio content written to file ' + fileName)
# Out:
# Audio content written to file ./audio_output/sample1_0.mp3
# Audio content written to file ./audio_output/sample2_0.mp3
# Audio content written to file ./audio_output/sample2_1.mp3
# Audio content written to file ./audio_output/sample2_2.mp3
# Audio content written to file ./audio_output/sample2_3.mp3
# Audio content written to file ./audio_output/sample2_4.mp3
# Audio content written to file ./audio_output/sample2_5.mp3
# Audio content written to file ./audio_output/sample2_6.mp3
# Audio content written to file ./audio_output/sample2_7.mp3
# Audio content written to file ./audio_output/sample2_8.mp3
# Audio content written to file ./audio_output/sample2_9.mp3
# Audio content written to file ./audio_output/sample3_0.mp3
# Audio content written to file ./audio_output/sample3_1.mp3
# Audio content written to file ./audio_output/sample3_2.mp3
# Audio content written to file ./audio_output/sample3_3.mp3
# Audio content written to file ./audio_output/sample3_4.mp3
# Audio content written to file ./audio_output/sample3_5.mp3
# Audio content written to file ./audio_output/sample3_6.mp3
# Audio content written to file ./audio_output/sample3_7.mp3
# Audio content written to file ./audio_output/sample3_8.mp3
# Audio content written to file ./audio_output/sample3_9.mp3
# Audio content written to file ./audio_output/sample4_0.mp3
# Audio content written to file ./audio_output/sample4_1.mp3
# Audio content written to file ./audio_output/sample4_2.mp3
# Audio content written to file ./audio_output/sample4_3.mp3
# Audio content written to file ./audio_output/sample4_4.mp3
# Audio content written to file ./audio_output/sample4_5.mp3
# Audio content written to file ./audio_output/sample4_6.mp3
# Audio content written to file ./audio_output/sample4_7.mp3
# Audio content written to file ./audio_output/sample4_8.mp3
# Audio content written to file ./audio_output/sample5_0.mp3
# Audio content written to file ./audio_output/sample5_1.mp3
# Audio content written to file ./audio_output/sample5_2.mp3
# Audio content written to file ./audio_output/sample5_3.mp3
# Audio content written to file ./audio_output/sample5_4.mp3
# Audio content written to file ./audio_output/sample6_0.mp3
# Audio content written to file ./audio_output/sample6_1.mp3
# Audio content written to file ./audio_output/sample6_2.mp3
# Audio content written to file ./audio_output/sample6_3.mp3
# Audio content written to file ./audio_output/sample6_4.mp3
# Audio content written to file ./audio_output/sample6_5.mp3
# Audio content written to file ./audio_output/sample6_6.mp3
# Audio content written to file ./audio_output/sample6_7.mp3
# Audio content written to file ./audio_output/sample6_8.mp3
# Audio content written to file ./audio_output/sample6_9.mp3
# Audio content written to file ./audio_output/sample7_0.mp3
# Audio content written to file ./audio_output/sample7_1.mp3
# Audio content written to file ./audio_output/sample7_2.mp3
# Audio content written to file ./audio_output/sample7_3.mp3
# Audio content written to file ./audio_output/sample7_4.mp3
# Audio content written to file ./audio_output/sample7_5.mp3
# Audio content written to file ./audio_output/sample7_6.mp3
# Audio content written to file ./audio_output/sample7_7.mp3
# Audio content written to file ./audio_output/sample7_8.mp3
# Audio content written to file ./audio_output/sample7_9.mp3
# Audio content written to file ./audio_output/sample7_10.mp3
# Audio content written to file ./audio_output/sample7_11.mp3
# Audio content written to file ./audio_output/sample7_12.mp3
# Audio content written to file ./audio_output/sample7_13.mp3
# Audio content written to file ./audio_output/sample7_14.mp3
# Audio content written to file ./audio_output/sample7_15.mp3
# Audio content written to file ./audio_output/sample8_0.mp3
# Audio content written to file ./audio_output/sample8_1.mp3
# Audio content written to file ./audio_output/sample8_2.mp3
# Audio content written to file ./audio_output/sample9_0.mp3
# Audio content written to file ./audio_output/sample9_1.mp3
# Audio content written to file ./audio_output/sample9_2.mp3
# Audio content written to file ./audio_output/sample9_3.mp3
# Audio content written to file ./audio_output/sample9_4.mp3
# Audio content written to file ./audio_output/sample9_5.mp3
# Audio content written to file ./audio_output/sample9_6.mp3
# Audio content written to file ./audio_output/sample10_0.mp3
# Audio content written to file ./audio_output/sample10_1.mp3
# Audio content written to file ./audio_output/sample10_2.mp3
# Audio content written to file ./audio_output/sample10_3.mp3
# Audio content written to file ./audio_output/sample10_4.mp3
# Audio content written to file ./audio_output/sample10_5.mp3
# Audio content written to file ./audio_output/sample10_6.mp3
# Audio content written to file ./audio_output/sample10_7.mp3
# Audio content written to file ./audio_output/sample10_8.mp3
# Audio content written to file ./audio_output/sample10_9.mp3
# Audio content written to file ./audio_output/sample10_10.mp3
# Audio content written to file ./audio_output/sample10_11.mp3
# Audio content written to file ./audio_output/sample11_0.mp3
# Audio content written to file ./audio_output/sample11_1.mp3
# Audio content written to file ./audio_output/sample11_2.mp3
# Audio content written to file ./audio_output/sample12_0.mp3
# Audio content written to file ./audio_output/sample12_1.mp3
# Audio content written to file ./audio_output/sample12_2.mp3
# Audio content written to file ./audio_output/sample12_3.mp3
# Audio content written to file ./audio_output/sample12_4.mp3
# Audio content written to file ./audio_output/sample12_5.mp3
# Audio content written to file ./audio_output/sample12_6.mp3
# Audio content written to file ./audio_output/sample12_7.mp3
# Audio content written to file ./audio_output/sample12_8.mp3
# Audio content written to file ./audio_output/sample12_9.mp3
# Audio content written to file ./audio_output/sample12_10.mp3
# Audio content written to file ./audio_output/sample12_11.mp3
# Audio content written to file ./audio_output/sample13_0.mp3
# Audio content written to file ./audio_output/sample13_1.mp3
# Audio content written to file ./audio_output/sample13_2.mp3
# Audio content written to file ./audio_output/sample13_3.mp3
# Audio content written to file ./audio_output/sample13_4.mp3
# Audio content written to file ./audio_output/sample13_5.mp3
# Audio content written to file ./audio_output/sample13_6.mp3
# Audio content written to file ./audio_output/sample13_7.mp3
# Audio content written to file ./audio_output/sample13_8.mp3
# Audio content written to file ./audio_output/sample13_9.mp3
# Audio content written to file ./audio_output/sample13_10.mp3
# Audio content written to file ./audio_output/sample13_11.mp3
# Audio content written to file ./audio_output/sample14_0.mp3
# Audio content written to file ./audio_output/sample14_1.mp3
# Audio content written to file ./audio_output/sample14_2.mp3
# Audio content written to file ./audio_output/sample14_3.mp3
# Audio content written to file ./audio_output/sample15_0.mp3
# Audio content written to file ./audio_output/sample15_1.mp3
# Audio content written to file ./audio_output/sample15_2.mp3
# Audio content written to file ./audio_output/sample15_3.mp3
# Audio content written to file ./audio_output/sample15_4.mp3
# Audio content written to file ./audio_output/sample15_5.mp3
# Audio content written to file ./audio_output/sample15_6.mp3
# Audio content written to file ./audio_output/sample15_7.mp3
# Audio content written to file ./audio_output/sample15_8.mp3
# Audio content written to file ./audio_output/sample15_9.mp3
# Audio content written to file ./audio_output/sample15_10.mp3
# Audio content written to file ./audio_output/sample15_11.mp3
# Audio content written to file ./audio_output/sample15_12.mp3
# Audio content written to file ./audio_output/sample15_13.mp3
# Audio content written to file ./audio_output/sample16_0.mp3
# Audio content written to file ./audio_output/sample16_1.mp3
# Audio content written to file ./audio_output/sample16_2.mp3
# Audio content written to file ./audio_output/sample16_3.mp3
# Audio content written to file ./audio_output/sample16_4.mp3
# Audio content written to file ./audio_output/sample16_5.mp3
# Audio content written to file ./audio_output/sample16_6.mp3
# Audio content written to file ./audio_output/sample16_7.mp3
# Audio content written to file ./audio_output/sample16_8.mp3
# Audio content written to file ./audio_output/sample16_9.mp3
# Audio content written to file ./audio_output/sample16_10.mp3
# Audio content written to file ./audio_output/sample16_11.mp3
# Audio content written to file ./audio_output/sample16_12.mp3
# Audio content written to file ./audio_output/sample17_0.mp3
# Audio content written to file ./audio_output/sample17_1.mp3
# Audio content written to file ./audio_output/sample17_2.mp3
# Audio content written to file ./audio_output/sample18_0.mp3
# Audio content written to file ./audio_output/sample18_1.mp3
# Audio content written to file ./audio_output/sample18_2.mp3
# Audio content written to file ./audio_output/sample19_0.mp3
# Audio content written to file ./audio_output/sample19_1.mp3
# Audio content written to file ./audio_output/sample19_2.mp3
# Audio content written to file ./audio_output/sample20_0.mp3
# Audio content written to file ./audio_output/sample20_1.mp3
# Audio content written to file ./audio_output/sample20_2.mp3
# Audio content written to file ./audio_output/sample21_0.mp3
# Audio content written to file ./audio_output/sample21_1.mp3
# Audio content written to file ./audio_output/sample21_2.mp3
# Audio content written to file ./audio_output/sample22_0.mp3
# Audio content written to file ./audio_output/sample22_1.mp3
# Audio content written to file ./audio_output/sample22_2.mp3
# Audio content written to file ./audio_output/sample22_3.mp3
# Audio content written to file ./audio_output/sample22_4.mp3
# Audio content written to file ./audio_output/sample22_5.mp3
# Audio content written to file ./audio_output/sample22_6.mp3
# Audio content written to file ./audio_output/sample22_7.mp3
# Audio content written to file ./audio_output/sample22_8.mp3
# Audio content written to file ./audio_output/sample22_9.mp3
# Audio content written to file ./audio_output/sample22_10.mp3
# Audio content written to file ./audio_output/sample22_11.mp3
# Audio content written to file ./audio_output/sample22_12.mp3
# Audio content written to file ./audio_output/sample23_0.mp3
# Audio content written to file ./audio_output/sample23_1.mp3
# Audio content written to file ./audio_output/sample24_0.mp3
# Audio content written to file ./audio_output/sample24_1.mp3
# Audio content written to file ./audio_output/sample24_2.mp3
# Audio content written to file ./audio_output/sample24_3.mp3
# Audio content written to file ./audio_output/sample24_4.mp3
# Audio content written to file ./audio_output/sample24_5.mp3
# Audio content written to file ./audio_output/sample24_6.mp3
# Audio content written to file ./audio_output/sample24_7.mp3
# Audio content written to file ./audio_output/sample24_8.mp3
# Audio content written to file ./audio_output/sample25_0.mp3
# Audio content written to file ./audio_output/sample25_1.mp3
# Audio content written to file ./audio_output/sample25_2.mp3
# Audio content written to file ./audio_output/sample25_3.mp3
# Audio content written to file ./audio_output/sample25_4.mp3
# Audio content written to file ./audio_output/sample25_5.mp3
# Audio content written to file ./audio_output/sample25_6.mp3
# Audio content written to file ./audio_output/sample25_7.mp3
# Audio content written to file ./audio_output/sample25_8.mp3
# Audio content written to file ./audio_output/sample25_9.mp3
# Audio content written to file ./audio_output/sample25_10.mp3
# Audio content written to file ./audio_output/sample25_11.mp3
# Audio content written to file ./audio_output/sample26_0.mp3
# Audio content written to file ./audio_output/sample26_1.mp3
# Audio content written to file ./audio_output/sample26_2.mp3
# Audio content written to file ./audio_output/sample26_3.mp3
# Audio content written to file ./audio_output/sample26_4.mp3
# Audio content written to file ./audio_output/sample26_5.mp3
# Audio content written to file ./audio_output/sample26_6.mp3
# Audio content written to file ./audio_output/sample26_7.mp3
# Audio content written to file ./audio_output/sample26_8.mp3
# Audio content written to file ./audio_output/sample26_9.mp3
# Audio content written to file ./audio_output/sample26_10.mp3
# Audio content written to file ./audio_output/sample27_0.mp3
# Audio content written to file ./audio_output/sample27_1.mp3
# Audio content written to file ./audio_output/sample27_2.mp3
# Audio content written to file ./audio_output/sample27_3.mp3
# Audio content written to file ./audio_output/sample27_4.mp3
# Audio content written to file ./audio_output/sample27_5.mp3
# Audio content written to file ./audio_output/sample27_6.mp3
# Audio content written to file ./audio_output/sample27_7.mp3
# Audio content written to file ./audio_output/sample27_8.mp3
# Audio content written to file ./audio_output/sample27_9.mp3
# Audio content written to file ./audio_output/sample27_10.mp3
# Audio content written to file ./audio_output/sample28_0.mp3
# Audio content written to file ./audio_output/sample28_1.mp3
# Audio content written to file ./audio_output/sample29_0.mp3
# Audio content written to file ./audio_output/sample29_1.mp3
# Audio content written to file ./audio_output/sample30_0.mp3
# Audio content written to file ./audio_output/sample30_1.mp3
# Audio content written to file ./audio_output/sample31_0.mp3
# Audio content written to file ./audio_output/sample31_1.mp3
# Audio content written to file ./audio_output/sample32_0.mp3
# Audio content written to file ./audio_output/sample32_1.mp3
# Audio content written to file ./audio_output/sample32_2.mp3
# Audio content written to file ./audio_output/sample32_3.mp3
# Audio content written to file ./audio_output/sample32_4.mp3
# Audio content written to file ./audio_output/sample32_5.mp3
# Audio content written to file ./audio_output/sample32_6.mp3
# Audio content written to file ./audio_output/sample32_7.mp3
# Audio content written to file ./audio_output/sample32_8.mp3
# Audio content written to file ./audio_output/sample32_9.mp3
# Audio content written to file ./audio_output/sample32_10.mp3
# Audio content written to file ./audio_output/sample32_11.mp3
# Audio content written to file ./audio_output/sample33_0.mp3
# Audio content written to file ./audio_output/sample33_1.mp3
# Audio content written to file ./audio_output/sample33_2.mp3
# Audio content written to file ./audio_output/sample34_0.mp3
# Audio content written to file ./audio_output/sample34_1.mp3
# Audio content written to file ./audio_output/sample34_2.mp3
# Audio content written to file ./audio_output/sample35_0.mp3
# Audio content written to file ./audio_output/sample35_1.mp3
# Audio content written to file ./audio_output/sample35_2.mp3
# Audio content written to file ./audio_output/sample35_3.mp3
# Audio content written to file ./audio_output/sample35_4.mp3
# Audio content written to file ./audio_output/sample35_5.mp3
# Audio content written to file ./audio_output/sample35_6.mp3
# Audio content written to file ./audio_output/sample35_7.mp3
# Audio content written to file ./audio_output/sample35_8.mp3
# Audio content written to file ./audio_output/sample35_9.mp3
# Audio content written to file ./audio_output/sample35_10.mp3
# Audio content written to file ./audio_output/sample35_11.mp3
# Audio content written to file ./audio_output/sample35_12.mp3
# Audio content written to file ./audio_output/sample36_0.mp3
# Audio content written to file ./audio_output/sample36_1.mp3
# Audio content written to file ./audio_output/sample36_2.mp3
# Audio content written to file ./audio_output/sample37_0.mp3
# Audio content written to file ./audio_output/sample37_1.mp3
# Audio content written to file ./audio_output/sample37_2.mp3
# Audio content written to file ./audio_output/sample38_0.mp3
# Audio content written to file ./audio_output/sample38_1.mp3
# Audio content written to file ./audio_output/sample38_2.mp3
# Audio content written to file ./audio_output/sample38_3.mp3
# Audio content written to file ./audio_output/sample38_4.mp3
# Audio content written to file ./audio_output/sample38_5.mp3
# Audio content written to file ./audio_output/sample38_6.mp3
# Audio content written to file ./audio_output/sample38_7.mp3
# Audio content written to file ./audio_output/sample38_8.mp3
# Audio content written to file ./audio_output/sample38_9.mp3
# Audio content written to file ./audio_output/sample38_10.mp3
# Audio content written to file ./audio_output/sample38_11.mp3
# Audio content written to file ./audio_output/sample38_12.mp3
# Audio content written to file ./audio_output/sample39_0.mp3
# Audio content written to file ./audio_output/sample39_1.mp3
# Audio content written to file ./audio_output/sample39_2.mp3
# Audio content written to file ./audio_output/sample39_3.mp3
# Audio content written to file ./audio_output/sample39_4.mp3
# Audio content written to file ./audio_output/sample39_5.mp3
# Audio content written to file ./audio_output/sample39_6.mp3
# Audio content written to file ./audio_output/sample39_7.mp3
# Audio content written to file ./audio_output/sample39_8.mp3
# Audio content written to file ./audio_output/sample39_9.mp3
# Audio content written to file ./audio_output/sample39_10.mp3
# Audio content written to file ./audio_output/sample39_11.mp3
# Audio content written to file ./audio_output/sample39_12.mp3
# Audio content written to file ./audio_output/sample39_13.mp3
# Audio content written to file ./audio_output/sample39_14.mp3
# Audio content written to file ./audio_output/sample39_15.mp3
# Audio content written to file ./audio_output/sample39_16.mp3
# Audio content written to file ./audio_output/sample40_0.mp3
# Audio content written to file ./audio_output/sample40_1.mp3
# Audio content written to file ./audio_output/sample40_2.mp3
# Audio content written to file ./audio_output/sample40_3.mp3
# Audio content written to file ./audio_output/sample40_4.mp3
# Audio content written to file ./audio_output/sample40_5.mp3
# Audio content written to file ./audio_output/sample40_6.mp3
# Audio content written to file ./audio_output/sample40_7.mp3
# Audio content written to file ./audio_output/sample41_0.mp3
# Audio content written to file ./audio_output/sample41_1.mp3
# Audio content written to file ./audio_output/sample41_2.mp3
# Audio content written to file ./audio_output/sample41_3.mp3
# Audio content written to file ./audio_output/sample41_4.mp3
# Audio content written to file ./audio_output/sample41_5.mp3
# Audio content written to file ./audio_output/sample41_6.mp3
# Audio content written to file ./audio_output/sample41_7.mp3
# Audio content written to file ./audio_output/sample41_8.mp3
# Audio content written to file ./audio_output/sample41_9.mp3
# Audio content written to file ./audio_output/sample41_10.mp3
# Audio content written to file ./audio_output/sample41_11.mp3
# Audio content written to file ./audio_output/sample42_0.mp3
# Audio content written to file ./audio_output/sample42_1.mp3
# Audio content written to file ./audio_output/sample43_0.mp3
# Audio content written to file ./audio_output/sample43_1.mp3
# Audio content written to file ./audio_output/sample44_0.mp3
# Audio content written to file ./audio_output/sample44_1.mp3
# Audio content written to file ./audio_output/sample44_2.mp3
# Audio content written to file ./audio_output/sample44_3.mp3
# Audio content written to file ./audio_output/sample44_4.mp3
# Audio content written to file ./audio_output/sample44_5.mp3
# Audio content written to file ./audio_output/sample44_6.mp3
# Audio content written to file ./audio_output/sample44_7.mp3
# Audio content written to file ./audio_output/sample44_8.mp3
# Audio content written to file ./audio_output/sample44_9.mp3
# Audio content written to file ./audio_output/sample45_0.mp3
# Audio content written to file ./audio_output/sample45_1.mp3
# Audio content written to file ./audio_output/sample45_2.mp3
# Audio content written to file ./audio_output/sample45_3.mp3
# Audio content written to file ./audio_output/sample45_4.mp3
# Audio content written to file ./audio_output/sample45_5.mp3
# Audio content written to file ./audio_output/sample46_0.mp3
# Audio content written to file ./audio_output/sample46_1.mp3
# Audio content written to file ./audio_output/sample46_2.mp3
# Audio content written to file ./audio_output/sample46_3.mp3
# Audio content written to file ./audio_output/sample46_4.mp3
# Audio content written to file ./audio_output/sample46_5.mp3
# Audio content written to file ./audio_output/sample46_6.mp3
# Audio content written to file ./audio_output/sample46_7.mp3
# Audio content written to file ./audio_output/sample46_8.mp3
# Audio content written to file ./audio_output/sample46_9.mp3
# Audio content written to file ./audio_output/sample46_10.mp3
