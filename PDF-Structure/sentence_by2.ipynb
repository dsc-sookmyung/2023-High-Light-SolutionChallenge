# %%
from pdfminer.high_level import extract_pages
from pdfminer.layout import LTTextContainer, LTChar,LTLine,LAParams
import os
path=r'./temp_dataset/os.pdf'

Extract_Data=[]

for page_layout in extract_pages(path):
    for element in page_layout:
        if isinstance(element, LTTextContainer):
            for text_line in element:
                for character in text_line:
                    if isinstance(character, LTChar):
                        Font_size=round(character.size)
            Extract_Data.append([Font_size,(element.get_text())])
            
print(Extract_Data)
# Out:
# [[40, '4장 쓰레드(thread)\n'], [32, '4장의 학습 목표\n'], [24, '• 프로세스와 쓰레드의 차이를 이해할 수 있다. \n'], [24, '• 쓰레드와 관련된 기본 설계 이슈를 설명할 수 있다. \n'], [24, '• 사용자 수준의 쓰레드와 커널 수준의 쓰레드의 차이를\n'], [24, '설명할 수 있다. \n'], [24, '• Windows의 쓰레드 관리 기능을 설명할 수 있다. \n'], [24, '• Solaris의 쓰레드 관리 기능을 설명할 수 있다. \n'], [24, '• Linux의 쓰레드 관리 기능을 설명할 수 있다. \n'], [24, '• Android의 쓰레드 관리 기능을 설명할 수 있다.\n'], [12, '2\n'], [32, '목 차\n'], [24, '4.1 프로세스 및 쓰레드(Thread)\n'], [24, '4.2 쓰레드의 유형\n'], [24, '4.3 멀티코어와 멀티쓰레딩\n'], [24, '4.4 Windows의 프로세스와 쓰레드 관리\n'], [24, '4.5 Solaris 쓰레드 및 SMP 관리\n'], [24, '4.6 Linux 프로세스 및 쓰레드 관리\n'], [24, '4.7 ANDROID의 프로세스와 쓰레드 관리\n'], [24, '4.8 Mac OS X의 Grand Central Dispatch\n'], [12, '3\n'], [32, '프로세스와 쓰레드(thread)\n'], [24, '• 프로세스\n'], [20, '– 실행 중인 프로그램(A program in execution)\n– 메모리 (코드, 데이터, 스택), 파일, signal, IPC, accounting, …\n– CPU 레지스터 정보, 스케줄링 정보\n'], [20, '\uf0e8 자원 소유권 (resource ownership)\n\uf0e8 수행/스케줄링\n'], [20, '(execution/scheduling) 개체\n'], [24, '• 현대 OS에서 프로세스는 태스크(task) 및 쓰레드(thread)\n'], [20, '라는 두 객체(특성)로 분리\n– 태스크: Resource Container (사용자 문맥, 시스템 문맥)\n– 쓰레드: 제어 흐름 (실행 정보, 레지스터 문맥)\n'], [18, '\uf046 쓰레드를 경량 프로세스(lightweight process)라고 부르기도 함\n\uf046 프로세스 및 태스크를 서로 혼용하여 사용하기도 함\n'], [12, '4\n'], [32, '프로세스와 쓰레드\n'], [24, '• 단일쓰레딩(Single threading) 대 멀티쓰레딩(Multi \n'], [24, 'threading)\n'], [20, '– 단일 프로세스 내에 멀티 쓰레드 실행을 지원 가능\n'], [12, '5\n'], [32, '프로세스와 쓰레드\n'], [24, '• 사례\n'], [20, '– MS-DOS는 단일 사용자 프로세스와 단일 쓰레드를 지원한다.\n'], [20, '– UNIX 계열의 여러 운영체제는 다중 사용자 프로세스를 지원하\n'], [20, '지만, 프로세스 당 하나의 쓰레드만을 지원한다.\n'], [20, '– Java 수행시간환경(run-time environment)은 하나의 프로세스가\n'], [20, '멀티 쓰레드를 지원한다.\n'], [20, '– 최신 버전의 UNIX, Windows, Solaris는 멀티쓰레드를 지원하는\n'], [20, '멀티 프로세스를 사용한다.\n'], [12, '6\n'], [32, '프로세스와 쓰레드\n'], [24, '• 멀티쓰레딩 환경\n'], [20, '– 태스크 (또는 프로세스) 관련 사항\n'], [18, '• 프로세스 이미지를 유지하는 가상 주소 공간\n'], [18, '• 처리기, (IPC를 위한) 다른 프로세스, 파일, I/O 자원들에 대한 접근\n'], [18, '제어\n'], [20, '– 쓰레드 관련 사항\n'], [18, '• 실행 상태 (수행, 준비, 블록, …)\n'], [18, '• 수행 중이 아닐 때 저장되는 쓰레드 문맥\n'], [18, '• 실행 스택\n'], [18, '• 지역 변수 저장을 위해 각 쓰레드가 사용하는 어떤 정적 저장소\n'], [18, '(storage)\n'], [18, '• 자신이 속한 프로세스의 메모리 및 자원들에 대한 접근 공유\n'], [20, '– 한 프로세스 내의 모든 쓰레드들은 그 프로세스의 자원들을 공\n'], [20, '유\n'], [12, '7\n'], [32, '프로세스와 쓰레드\n'], [24, '• 쓰레드 모델 (그림 4.2)\n'], [12, '8\n'], [32, '프로세스와 쓰레드\n'], [24, '• 쓰레드의 장점(benefits)\n'], [20, '– 프로세스에 비해 새로운 쓰레드 생성 시간/비용이 절약됨: (쓰레\n'], [20, '드 생성시간은 프로세스보다 수십 배 빠르다.)\n– 프로세스 종료 시간보다 쓰레드 종료 시간이 짧다.\n– 한 프로세스 내의 두 쓰레드들 사이의 교환/교체 시간이 짧다.\n– 동일 프로세스 내의 쓰레드들은 메모리 및 파일을 공유하기 때\n'], [20, '문에, 이들 쓰레드들은 커널의 개입 없이 서로 통신 가능\n'], [20, '– 한 프로그램의 구조(structure)를 단순화\n– 다중처리기(multiprocessor)의 효율적 사용\n– 빠른 IPC (메시지 전송이 아닌 공유 메모리 사용 가능)\n– 병행 서버 (listening thread and responding threads)\n'], [12, '9\n'], [32, '프로세스와 쓰레드\n'], [20, '• 단일사용자 멀티프로세싱 시스템에서의 쓰레드의 사용\n'], [17, '- 전면(foreground)과 후면(background) 작업: 응용의 속도 향상\n'], [14, '• 예를 들어, 스프레드시트 프로그램에서 하나의 쓰레드가 메뉴를 나타내고 사용자 입력을\n읽는 중에, 다른 쓰레드는 사용자 명령을 수행하고 스프레드시트를 갱신할 수 있다. \n'], [17, '- 비동기(asynchronous) 처리: \n'], [14, '• 프로그램의 비동기적 요소들을 쓰레드를 통해 구현할 수 있다. 예) 정전으로부터 보호하\n기 위해 1분마다 메모리(RAM) 버퍼의 내용을 디스크로 기록하는 워드 프로세서를 설계\n할 수 있다. 이를 위한 쓰레드가 생성될 수 있는데, 유일한 업무는 주기적인 백업이며 운\n영체제를 통해 직접 자신을 스케줄 한다. 이때 시간을 검사하거나 또는 입력 및 출력을\n조정하기 위해 주 프로그램 내에 복잡한 코드를 작성할 필요는 없다. \n'], [17, '- 빠른 수행: \n'], [14, '• 멀티쓰레드 프로세스는 어떤 데이터 묶음(batch)을 계산하면서 동시에 어떤 장치로부터\n다음 데이터 묶음을 읽어 들일 수 있다. 멀티프로세스시스템에서 한 프로세스 내의 여러\n쓰레드들은 실제적으로 동시에 수행될 수 있다. 따라서 한 쓰레드가 특정 데이터 묶음을\n읽기 위해 입출력 작업 완료를 기다리면서 블록(block)될지라도, 또 다른 쓰레드가 수행\n될 수 있다. \n'], [17, '– 모듈 프로그램 구조: \n'], [14, '• 다양한 활동 혹은 입출력 연산에 대한 다양한 출발ㆍ목적지를 포함하고 있는 프로그램의\n'], [14, '경우, 쓰레드들을 사용하여 설계하고 구현하는 것이 편리하다. \n'], [12, '10\n'], [32, '프로세스와 쓰레드\n'], [24, '• 쓰레드의 장점: 예 (그림 4.3: RPC(Remote Procedure Call) )\n'], [12, '11\n'], [32, '프로세스와 쓰레드\n'], [24, '• 쓰레드의 기능(thread functionality)\n'], [20, '– 쓰레드 상태\n'], [18, '• 수행, 준비, 블록\n'], [18, '• 기본적인 쓰레드 연산:\n'], [18, '\uf046 보류(Suspended)고 가능 ?\n'], [18, '– 생성(Spawn), 디스패치(Dispatch), 블록(Block), 비블록(Unblock), \n'], [18, '종료(Finish)\n'], [18, '• 그림 4.4: ...
